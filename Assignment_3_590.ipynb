# %% [markdown]
# <a href="https://colab.research.google.com/github/19K41A0590/AI/blob/main/Assignment_3_590.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2021-09-05 at 8.27.05 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-09-05 at 8.27.05 PM (1).jpeg](data:image/jpeg;base64,...)

# %%
import math
x=0
y=0
eta=0.00001
eps=0.1
delx=1
dely=1
e=2.178
max_iter=1000
iter=0
def deriv(x,y):
  xderive=6*x
  yderive=-5*pow(e,-y)
  return xderive,yderive

# %%
while max(abs(delx),abs(dely))>eps and iter<max_iter:
  prevx=x
  prevy=y
  delx,dely=deriv(prevx,prevy)
  delx=-eta*delx
  dely=-eta*dely
  x=x+delx
  y=y+dely
  iter=iter+1
print("value of x = ",round(x),"\nValue of y = ",round(y));
obj=3*x*x+5*pow(e,-y)+10
print("Value of objective function is ",round(obj))
# Out:
# value of x =  0
# Value of y =  0
# Value of objective function is  15
